# %% [markdown]
# # Importación de librerías

# %%
import pandas as pd

# %% [markdown]
# # Ingesta de datos

# %% [markdown]
# ## Insumos

# %%
insumos = pd.read_excel("data\INSUMOS OPERACIONALES STOCK RELIX.xlsx", sheet_name='Insumos Operacionales 2025', skiprows=7)

# %%
insumos.head()
# Out:
#    Unnamed: 0  ITEM  CODIGO SAP/OTRO  \
# 0         NaN   1.1         11174821
# 1         NaN   1.2         11177716
# 2         NaN   1.3  en catalogacion
# 3         NaN   1.4         11151921
# 4         NaN   1.5         11019704
#
#                            DESCRIPCION DEL MATERIAL  CLASIFICACIÓN  U M  \
# 0              DUCTO RECTO;PE100;PN20;280 MM;12 M;PL        PIPING   UN
# 1      DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL - 8" diam        PIPING   UN
# 2  Tuberia HDPE 200MM DN, Flanges Moviles C150, c...        PIPING   UN
# 3  DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL - 8" diam ...        PIPING   UN
# 4                DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL        PIPING   UN
#
#    OBSERVACIONES Unnamed: 7
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN

# %%
insumos = insumos.drop(insumos.columns[[0, 7]], axis=1)
insumos.head()
# Out:
#    ITEM  CODIGO SAP/OTRO                          DESCRIPCION DEL MATERIAL   \
# 0   1.1         11174821              DUCTO RECTO;PE100;PN20;280 MM;12 M;PL
# 1   1.2         11177716      DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL - 8" diam
# 2   1.3  en catalogacion  Tuberia HDPE 200MM DN, Flanges Moviles C150, c...
# 3   1.4         11151921  DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL - 8" diam ...
# 4   1.5         11019704                DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL
#
#   CLASIFICACIÓN  U M  OBSERVACIONES
# 0        PIPING   UN            NaN
# 1        PIPING   UN            NaN
# 2        PIPING   UN            NaN
# 3        PIPING   UN            NaN
# 4        PIPING   UN            NaN

# %%
insumos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ITEM                       490 non-null    float64
#  1   CODIGO SAP/OTRO            490 non-null    object
#  2   DESCRIPCION DEL MATERIAL   490 non-null    object
#  3   CLASIFICACIÓN              490 non-null    object
#  4   U M                        486 non-null    object
#  5   OBSERVACIONES              0 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 23.1+ KB

# %%
insumos.columns
# Out:
# Index(['ITEM', 'CODIGO SAP/OTRO', 'DESCRIPCION DEL MATERIAL ',
#        'CLASIFICACIÓN ', 'U M', 'OBSERVACIONES'],
#       dtype='object')

# %%
insumos.columns = insumos.columns.str.strip()

# %%
insumos[insumos['CLASIFICACIÓN'].isnull()]
# TODO: llenar clasificación NaN
# Out:
#       ITEM CODIGO SAP/OTRO                      DESCRIPCION DEL MATERIAL  \
# 481  11.29        11220592  MAURO TUERCA STORZ 4 PULGADAS LINEA DE RIEGO
#
#     CLASIFICACIÓN U M  OBSERVACIONES
# 481           NaN  UN            NaN

# %%
insumos['CLASIFICACIÓN'].unique()
# Out:
# array(['PIPING ', 'PIEZAS ESPECIALES', 'VALVULAS', 'HUMECTACIÓN ',
#        'PIEZÓMETROS ', 'IMPERMEABILIAZACIÓN ', 'OBRAS CIVILES ',
#        'SERVICIOS GENERALES', 'ILUMINACION EMPALIZADA', 'TALLER BERLIAM',
#        nan, 'RIEGO MURO TRANQUE', 'INSTRUMENTACIÓN GEOTECNICA'],
#       dtype=object)

# %%
insumos['CLASIFICACIÓN'] = insumos['CLASIFICACIÓN'].str.strip()
insumos['CLASIFICACIÓN'].unique()
# Out:
# array(['PIPING', 'PIEZAS ESPECIALES', 'VALVULAS', 'HUMECTACIÓN',
#        'PIEZÓMETROS', 'IMPERMEABILIAZACIÓN', 'OBRAS CIVILES',
#        'SERVICIOS GENERALES', 'ILUMINACION EMPALIZADA', 'TALLER BERLIAM',
#        nan, 'RIEGO MURO TRANQUE', 'INSTRUMENTACIÓN GEOTECNICA'],
#       dtype=object)

# %%
insumos[insumos['CODIGO SAP/OTRO'].isnull()]
# TODO: Considerar iluminación empalizada como categoría?
# Out:
#      ITEM CODIGO SAP/OTRO DESCRIPCION DEL MATERIAL           CLASIFICACIÓN  \
# 490   NaN             NaN                      NaN  ILUMINACION EMPALIZADA
#
#      U M  OBSERVACIONES
# 490  NaN            NaN

# %%
insumos[insumos['U M'].isnull()]
# Out:
#      ITEM CODIGO SAP/OTRO                 DESCRIPCION DEL MATERIAL  \
# 166  4.40   catalogar sap          Flange Ciego diam 28" ANSI C150
# 167  4.50   catalogar sap               Flange Ciego 28" ANSI C300
# 348  9.95   catalogar sap          Tubos PVC Bastones Reflectantes
# 352  9.99        11215216  BOQUILLAS DEPOSITACION 50MM POLIURETANO
# 490   NaN             NaN                                      NaN
#
#               CLASIFICACIÓN  U M  OBSERVACIONES
# 166       PIEZAS ESPECIALES  NaN            NaN
# 167       PIEZAS ESPECIALES  NaN            NaN
# 348     SERVICIOS GENERALES  NaN            NaN
# 352     SERVICIOS GENERALES  NaN            NaN
# 490  ILUMINACION EMPALIZADA  NaN            NaN

# %%
insumos['U M'].unique()
# TODO: Corregir UM inconsistentes
# Out:
# array(['UN', nan, 'kit', 'Bins', 'M2', 'ROLLOS', 'M3', 'M', 'kg', 'Mt',
#        'Kg', 'Metros', 'KIT', 'lts', 'mt', 'Unidad', 'Bin', 'Rollo',
#        'saco 25 kg', 'Kit'], dtype=object)

# %%
insumos.head(3)
# Out:
#    ITEM  CODIGO SAP/OTRO                           DESCRIPCION DEL MATERIAL  \
# 0   1.1         11174821              DUCTO RECTO;PE100;PN20;280 MM;12 M;PL
# 1   1.2         11177716      DUCTO;HDPE;12MT;PE100;PN12,5;F01;PL - 8" diam
# 2   1.3  en catalogacion  Tuberia HDPE 200MM DN, Flanges Moviles C150, c...
#
#   CLASIFICACIÓN U M  OBSERVACIONES
# 0        PIPING  UN            NaN
# 1        PIPING  UN            NaN
# 2        PIPING  UN            NaN

# %%
insumos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ITEM                      490 non-null    float64
#  1   CODIGO SAP/OTRO           490 non-null    object
#  2   DESCRIPCION DEL MATERIAL  490 non-null    object
#  3   CLASIFICACIÓN             490 non-null    object
#  4   U M                       486 non-null    object
#  5   OBSERVACIONES             0 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 23.1+ KB

# %% [markdown]
# ## Ingresos

# %%
ingresos = pd.read_excel("data\INSUMOS OPERACIONALES STOCK RELIX.xlsx", sheet_name='INGRESO', skiprows=9)

# %%
ingresos.head()
# Out:
#    Unnamed: 0       CLASIFICIACIÓN  CÓDIGO         SAP/OTRO  \
# 0         NaN              VALVULAS                11178702
# 1         NaN              VALVULAS                11117559
# 2         NaN  IMPERMEABILIAZACIÓN                 11019930
# 3         NaN  IMPERMEABILIAZACIÓN                 11019930
# 4         NaN  IMPERMEABILIAZACIÓN                 11019930
#
#                             DESCRIPCIÓN DEL MATERIAL UNIDAD  CANTIDAD  \
# 0  Valvula 8"clase 300 (L)\nVÁLVULA;FLSMIDTH;TGHP...     UN       8.0
# 1  Válvula Cuchillo 8" FL  (c 150)\nVALVULA CUCHI...     UN      20.0
# 2              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 3              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 4              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
#
#   FECHA DE INGRESO RESERVA  GUIA DESPACHO          OC  \
# 0       2025-09-25  5080832        135973  4510237047
# 1       2025-09-25  4947998        135974  4510231212
# 2       2025-09-28  5152005        151237  4510240486
# 3       2025-09-28  5152005        151157  4510240486
# 4       2025-09-28  5152005        151017  4510240486
#
#   USO:  OPERCIONES / PROYECTO   RECIBIDO POR:          UBICACIÓN  \
# 0                EMPALIZADA 23  KAREM GONZALEZ  PATIO EX COSAPIN
# 1                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 2                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 3                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 4                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
#
#         EMPRESA  PRECIO UNITARIO  TOTAL NETO OBSERVACIONES
# 0  FLSMIDTH S.A       11035478.0  88283824.0           NaN
# 1  FLSMIDTH S.A        2783917.0  55678340.0           NaN
# 2   POLYTEX S.A           2173.0   6397312.0           NaN
# 3   POLYTEX S.A           2169.0   6385536.0           NaN
# 4   POLYTEX S.A           2205.0   6491520.0           NaN

# %%
ingresos = ingresos.drop(ingresos.columns[0], axis=1)
ingresos.head()
# Out:
#         CLASIFICIACIÓN  CÓDIGO         SAP/OTRO  \
# 0              VALVULAS                11178702
# 1              VALVULAS                11117559
# 2  IMPERMEABILIAZACIÓN                 11019930
# 3  IMPERMEABILIAZACIÓN                 11019930
# 4  IMPERMEABILIAZACIÓN                 11019930
#
#                             DESCRIPCIÓN DEL MATERIAL UNIDAD  CANTIDAD  \
# 0  Valvula 8"clase 300 (L)\nVÁLVULA;FLSMIDTH;TGHP...     UN       8.0
# 1  Válvula Cuchillo 8" FL  (c 150)\nVALVULA CUCHI...     UN      20.0
# 2              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 3              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 4              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
#
#   FECHA DE INGRESO RESERVA  GUIA DESPACHO          OC  \
# 0       2025-09-25  5080832        135973  4510237047
# 1       2025-09-25  4947998        135974  4510231212
# 2       2025-09-28  5152005        151237  4510240486
# 3       2025-09-28  5152005        151157  4510240486
# 4       2025-09-28  5152005        151017  4510240486
#
#   USO:  OPERCIONES / PROYECTO   RECIBIDO POR:          UBICACIÓN  \
# 0                EMPALIZADA 23  KAREM GONZALEZ  PATIO EX COSAPIN
# 1                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 2                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 3                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 4                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
#
#         EMPRESA  PRECIO UNITARIO  TOTAL NETO OBSERVACIONES
# 0  FLSMIDTH S.A       11035478.0  88283824.0           NaN
# 1  FLSMIDTH S.A        2783917.0  55678340.0           NaN
# 2   POLYTEX S.A           2173.0   6397312.0           NaN
# 3   POLYTEX S.A           2169.0   6385536.0           NaN
# 4   POLYTEX S.A           2205.0   6491520.0           NaN

# %%
ingresos.columns
# Out:
# Index(['CLASIFICIACIÓN ', 'CÓDIGO         SAP/OTRO',
#        'DESCRIPCIÓN DEL MATERIAL', 'UNIDAD', 'CANTIDAD', 'FECHA DE INGRESO',
#        'RESERVA ', 'GUIA DESPACHO', 'OC', 'USO:  OPERCIONES / PROYECTO ',
#        'RECIBIDO POR: ', 'UBICACIÓN', 'EMPRESA', 'PRECIO UNITARIO',
#        'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %%
ingresos.columns = ingresos.columns.str.strip()
ingresos.columns
# Out:
# Index(['CLASIFICIACIÓN', 'CÓDIGO         SAP/OTRO', 'DESCRIPCIÓN DEL MATERIAL',
#        'UNIDAD', 'CANTIDAD', 'FECHA DE INGRESO', 'RESERVA', 'GUIA DESPACHO',
#        'OC', 'USO:  OPERCIONES / PROYECTO', 'RECIBIDO POR:', 'UBICACIÓN',
#        'EMPRESA', 'PRECIO UNITARIO', 'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %%
ingresos = ingresos.rename(columns={'CÓDIGO         SAP/OTRO': 'CODIGO SAP/OTRO'})
ingresos.columns
# Out:
# Index(['CLASIFICIACIÓN', 'CODIGO SAP/OTRO', 'DESCRIPCIÓN DEL MATERIAL',
#        'UNIDAD', 'CANTIDAD', 'FECHA DE INGRESO', 'RESERVA', 'GUIA DESPACHO',
#        'OC', 'USO:  OPERCIONES / PROYECTO', 'RECIBIDO POR:', 'UBICACIÓN',
#        'EMPRESA', 'PRECIO UNITARIO', 'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %% [markdown]
# ## Salidas

# %%
salidas = pd.read_excel("data\INSUMOS OPERACIONALES STOCK RELIX.xlsx", sheet_name='SALIDA', skiprows=9)

# %%
salidas.head()
# Out:
#    Unnamed: 0 CLASIFICIACIÓN  CÓDIGO         SAP / OTRO  \
# 0         NaN        VALVULAS                  11117559
# 1         NaN        VALVULAS                  22002942
# 2         NaN        VALVULAS                  22003670
# 3         NaN         PIPING                   11188685
# 4         NaN         PIPING                   11009709
#
#                             DESCRIPCIÓN DEL MATERIAL UNIDAD  CANTIDAD  \
# 0  Válvula Cuchillo 8" FL  (c 150)\nVALVULA CUCHI...     UN       6.0
# 1                    ESPARRAGO;7/8" X 1MT LG GRADO 5     UN      12.0
# 2                     ESPARRAGO;7/8" X 8" LG GRADO 5     UN      64.0
# 3  EMPAQ. FF DN- 10" # 300 EN BA-U 1/8" S/ANSI B ...     UN       6.0
# 4                   EMPAQUETADURA;8" ANSI 150 8 PERF     UN      10.0
#
#        FECHA DE SALIDA  N° DE GUÍA DE SALIDAD USO:  OPERACIONES / PROYECTO   \
# 0  2025-09-30 00:00:00                    NaN                   OPERACIONES
# 1  2025-10-09 00:00:00                    NaN                   OPERACIONES
# 2  2025-10-09 00:00:00                    NaN                   OPERACIONES
# 3  2025-10-09 00:00:00                    NaN                   OPERACIONES
# 4  2025-10-10 00:00:00                    NaN                   OPERACIONES
#
#     ENTREGADO  A:       COMENTARIOS UBICACIÓN DE RETIRO Unnamed: 12
# 0     RENE MENDOZA       EMPALIZADA              COSAPI         NaN
# 1  NELSON AGUILERA  TALLER SOLDADOR        BODEGA RELIX         NaN
# 2   ANIBAL ESCOBAR       EMPALIZADA        BODEGA RELIX         NaN
# 3     HUGO SALAZAR       EMPALIZADA        BODEGA RELIX         NaN
# 4     ERNESTO DIAZ   LINEA PEUMO L3        BODEGA RELIX         NaN

# %%
salidas = salidas.drop(salidas.columns[[0, 12]], axis=1)
salidas.head()
# Out:
#   CLASIFICIACIÓN  CÓDIGO         SAP / OTRO  \
# 0        VALVULAS                  11117559
# 1        VALVULAS                  22002942
# 2        VALVULAS                  22003670
# 3         PIPING                   11188685
# 4         PIPING                   11009709
#
#                             DESCRIPCIÓN DEL MATERIAL UNIDAD  CANTIDAD  \
# 0  Válvula Cuchillo 8" FL  (c 150)\nVALVULA CUCHI...     UN       6.0
# 1                    ESPARRAGO;7/8" X 1MT LG GRADO 5     UN      12.0
# 2                     ESPARRAGO;7/8" X 8" LG GRADO 5     UN      64.0
# 3  EMPAQ. FF DN- 10" # 300 EN BA-U 1/8" S/ANSI B ...     UN       6.0
# 4                   EMPAQUETADURA;8" ANSI 150 8 PERF     UN      10.0
#
#        FECHA DE SALIDA  N° DE GUÍA DE SALIDAD USO:  OPERACIONES / PROYECTO   \
# 0  2025-09-30 00:00:00                    NaN                   OPERACIONES
# 1  2025-10-09 00:00:00                    NaN                   OPERACIONES
# 2  2025-10-09 00:00:00                    NaN                   OPERACIONES
# 3  2025-10-09 00:00:00                    NaN                   OPERACIONES
# 4  2025-10-10 00:00:00                    NaN                   OPERACIONES
#
#     ENTREGADO  A:       COMENTARIOS UBICACIÓN DE RETIRO
# 0     RENE MENDOZA       EMPALIZADA              COSAPI
# 1  NELSON AGUILERA  TALLER SOLDADOR        BODEGA RELIX
# 2   ANIBAL ESCOBAR       EMPALIZADA        BODEGA RELIX
# 3     HUGO SALAZAR       EMPALIZADA        BODEGA RELIX
# 4     ERNESTO DIAZ   LINEA PEUMO L3        BODEGA RELIX

# %%
salidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CLASIFICIACIÓN                 341 non-null    object
#  1   CÓDIGO         SAP / OTRO      341 non-null    object
#  2   DESCRIPCIÓN DEL MATERIAL       341 non-null    object
#  3   UNIDAD                         341 non-null    object
#  4   CANTIDAD                       341 non-null    float64
#  5   FECHA DE SALIDA                341 non-null    object
#  6   N° DE GUÍA DE SALIDAD          0 non-null      float64
#  7   USO:  OPERACIONES / PROYECTO   341 non-null    object
#  8   ENTREGADO  A:                  341 non-null    object
#  9   COMENTARIOS                    339 non-null    object
#  10  UBICACIÓN DE RETIRO            275 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 48.2+ KB

# %%
salidas['ENTREGADO  A: '].unique()
# Out:
# array(['RENE MENDOZA', 'NELSON AGUILERA', 'ANIBAL ESCOBAR',
#        'HUGO SALAZAR', 'ERNESTO DIAZ', 'VICTOR PEREZ ', 'CLAUDIO VERA',
#        'MOISES SILVA', 'ALEXANDER PINO', 'VICTOR GACITUA',
#        'CAROLINA LAGOS', 'CAMILO MALAVE', 'SEBASTIAN MUÑOZ',
#        'VICTO PEREZ', 'ARIEL SALAS', 'CLAUDIO RIVERA', 'NELSON INZUNZA',
#        'JOSE SIERRA ', 'RAUL RIVERA', 'JORGE VASQUEZ',
#        'IGNACIO VALENZUELA', 'FELIPE ROJAS', 'ALEXANDER CID',
#        'CARLOS GOYCOLEA', 'ANDRES VILLALOBOS', 'PAULINA CASTILLO',
#        'JOSE LOPEZ', 'FRANCISCO AVELLO', 'SEBASTIAN CORDOBA',
#        'LUIS ROBLES', 'ALEJANDRO ROJAS', 'JOSE SIERRA', nan], dtype=object)

# %%
salidas = salidas[salidas['CÓDIGO         SAP / OTRO'].isnull()]
salidas
# Out:
#     CLASIFICIACIÓN  CÓDIGO         SAP / OTRO DESCRIPCIÓN DEL MATERIAL UNIDAD  \
# 341             NaN                       NaN                      NaN    NaN
# 342             NaN                       NaN                      NaN    NaN
# 343             NaN                       NaN                      NaN    NaN
# 344             NaN                       NaN                      NaN    NaN
# 345             NaN                       NaN                      NaN    NaN
# ..              ...                       ...                      ...    ...
# 555             NaN                       NaN                      NaN    NaN
# 556             NaN                       NaN                      NaN    NaN
# 557             NaN                       NaN                      NaN    NaN
# 558             NaN                       NaN                      NaN    NaN
# 559             NaN                       NaN                      NaN    NaN
#
#      CANTIDAD FECHA DE SALIDA  N° DE GUÍA DE SALIDAD  \
# 341       NaN             NaN                    NaN
# 342       NaN             NaN                    NaN
# 343       NaN             NaN                    NaN
# 344       NaN             NaN                    NaN
# 345       NaN             NaN                    NaN
# ..        ...             ...                    ...
# 555       NaN             NaN                    NaN
# 556       NaN             NaN                    NaN
# 557       NaN             NaN                    NaN
# 558       NaN             NaN                    NaN
# 559       NaN             NaN                    NaN
#
#     USO:  OPERACIONES / PROYECTO  ENTREGADO  A:  COMENTARIOS  \
# 341                           NaN            NaN         NaN
# 342                           NaN            NaN         NaN
# 343                           NaN            NaN         NaN
# 344                           NaN            NaN         NaN
# 345                           NaN            NaN         NaN
# ..                            ...            ...         ...
# 555                           NaN            NaN         NaN
# 556                           NaN            NaN         NaN
# 557                           NaN            NaN         NaN
# 558                           NaN            NaN         NaN
# 559                           NaN            NaN         NaN
#
#     UBICACIÓN DE RETIRO
# 341                 NaN
# 342                 NaN
# 343                 NaN
# 344                 NaN
# 345                 NaN
# ..                  ...
# 555                 NaN
# 556                 NaN
# 557                 NaN
# 558                 NaN
# 559                 NaN
#
# [219 rows x 11 columns]

# %%
salidas = salidas.dropna(subset=['CODIGO         SAP / OTRO'])
salidas
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_60968\407313.py in ?()
# ----> 1 salidas = salidas.dropna(subset=['CODIGO         SAP / OTRO'])
#       2 salidas
#
# c:\Users\rcsma\Desktop\Tesis Patricio Zuñiga BD\inventario_app\entornovirtual\lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6688             ax = self._get_axis(agg_axis)
#    6689             indices = ax.get_indexer_for(subset)
#    6690             check = indices == -1
#    6691             if check.any():
# -> 6692                 raise KeyError(np.array(subset)[check].tolist())
#    6693             agg_obj = self.take(indices, axis=agg_axis)
#    6694
#    6695         if thresh is not lib.no_default:
#
# KeyError: ['CODIGO         SAP / OTRO']
