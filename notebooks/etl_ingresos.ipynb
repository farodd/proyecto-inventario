# %% [markdown]
# # Importación de librerías

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # Ingesta de datos

# %%
ingresos = pd.read_excel("..\data\INSUMOS OPERACIONALES STOCK RELIX.xlsx", sheet_name='INGRESO', skiprows=9)

# %%
ingresos.head()
# Out:
#    Unnamed: 0       CLASIFICIACIÓN  CÓDIGO         SAP/OTRO  \
# 0         NaN              VALVULAS                11178702
# 1         NaN              VALVULAS                11117559
# 2         NaN  IMPERMEABILIAZACIÓN                 11019930
# 3         NaN  IMPERMEABILIAZACIÓN                 11019930
# 4         NaN  IMPERMEABILIAZACIÓN                 11019930
#
#                             DESCRIPCIÓN DEL MATERIAL UNIDAD  CANTIDAD  \
# 0  Valvula 8"clase 300 (L)\nVÁLVULA;FLSMIDTH;TGHP...     UN       8.0
# 1  Válvula Cuchillo 8" FL  (c 150)\nVALVULA CUCHI...     UN      20.0
# 2              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 3              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 4              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
#
#   FECHA DE INGRESO RESERVA  GUIA DESPACHO          OC  \
# 0       2025-09-25  5080832        135973  4510237047
# 1       2025-09-25  4947998        135974  4510231212
# 2       2025-09-28  5152005        151237  4510240486
# 3       2025-09-28  5152005        151157  4510240486
# 4       2025-09-28  5152005        151017  4510240486
#
#   USO:  OPERCIONES / PROYECTO   RECIBIDO POR:          UBICACIÓN  \
# 0                EMPALIZADA 23  KAREM GONZALEZ  PATIO EX COSAPIN
# 1                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 2                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 3                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 4                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
#
#         EMPRESA  PRECIO UNITARIO  TOTAL NETO OBSERVACIONES
# 0  FLSMIDTH S.A       11035478.0  88283824.0           NaN
# 1  FLSMIDTH S.A        2783917.0  55678340.0           NaN
# 2   POLYTEX S.A           2173.0   6397312.0           NaN
# 3   POLYTEX S.A           2169.0   6385536.0           NaN
# 4   POLYTEX S.A           2205.0   6491520.0           NaN

# %% [markdown]
# # Transformación

# %% [markdown]
# ## Columnas

# %%
# Eliminar columna vacia inicial
ingresos = ingresos.drop(ingresos.columns[0], axis=1)
ingresos.head()
# Out:
#         CLASIFICIACIÓN  CÓDIGO         SAP/OTRO  \
# 0              VALVULAS                11178702
# 1              VALVULAS                11117559
# 2  IMPERMEABILIAZACIÓN                 11019930
# 3  IMPERMEABILIAZACIÓN                 11019930
# 4  IMPERMEABILIAZACIÓN                 11019930
#
#                             DESCRIPCIÓN DEL MATERIAL UNIDAD  CANTIDAD  \
# 0  Valvula 8"clase 300 (L)\nVÁLVULA;FLSMIDTH;TGHP...     UN       8.0
# 1  Válvula Cuchillo 8" FL  (c 150)\nVALVULA CUCHI...     UN      20.0
# 2              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 3              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
# 4              GEOMEMBRANA;7.01X210MT 1.5MM ESP HDPE     M2    2944.0
#
#   FECHA DE INGRESO RESERVA  GUIA DESPACHO          OC  \
# 0       2025-09-25  5080832        135973  4510237047
# 1       2025-09-25  4947998        135974  4510231212
# 2       2025-09-28  5152005        151237  4510240486
# 3       2025-09-28  5152005        151157  4510240486
# 4       2025-09-28  5152005        151017  4510240486
#
#   USO:  OPERCIONES / PROYECTO   RECIBIDO POR:          UBICACIÓN  \
# 0                EMPALIZADA 23  KAREM GONZALEZ  PATIO EX COSAPIN
# 1                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 2                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 3                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
# 4                  OPERACIONES  KAREM GONZALEZ  PATIO EX COSAPIN
#
#         EMPRESA  PRECIO UNITARIO  TOTAL NETO OBSERVACIONES
# 0  FLSMIDTH S.A       11035478.0  88283824.0           NaN
# 1  FLSMIDTH S.A        2783917.0  55678340.0           NaN
# 2   POLYTEX S.A           2173.0   6397312.0           NaN
# 3   POLYTEX S.A           2169.0   6385536.0           NaN
# 4   POLYTEX S.A           2205.0   6491520.0           NaN

# %%
ingresos.columns
# Out:
# Index(['CLASIFICIACIÓN ', 'CÓDIGO         SAP/OTRO',
#        'DESCRIPCIÓN DEL MATERIAL', 'UNIDAD', 'CANTIDAD', 'FECHA DE INGRESO',
#        'RESERVA ', 'GUIA DESPACHO', 'OC', 'USO:  OPERCIONES / PROYECTO ',
#        'RECIBIDO POR: ', 'UBICACIÓN', 'EMPRESA', 'PRECIO UNITARIO',
#        'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %%
# Eliminar espacios en los nombres de las columnas
ingresos.columns = ingresos.columns.str.strip()
ingresos.columns
# Out:
# Index(['CLASIFICIACIÓN', 'CÓDIGO         SAP/OTRO', 'DESCRIPCIÓN DEL MATERIAL',
#        'UNIDAD', 'CANTIDAD', 'FECHA DE INGRESO', 'RESERVA', 'GUIA DESPACHO',
#        'OC', 'USO:  OPERCIONES / PROYECTO', 'RECIBIDO POR:', 'UBICACIÓN',
#        'EMPRESA', 'PRECIO UNITARIO', 'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %%
# Estandarización de nombre de columnas y eliminación de espacios
ingresos = ingresos.rename(columns={'CÓDIGO         SAP/OTRO': 'CODIGO SAP', 
                                    'CLASIFICIACIÓN': 'CLASIFICACION', 
                                    'DESCRIPCIÓN DEL MATERIAL': 'DESCRIPCION DEL MATERIAL', 
                                    'UNIDAD': 'UM',
                                    'UBICACIÓN': 'UBICACION',
                                    'RECIBIDO POR:': 'RECIBIDO POR',
                                    'USO:  OPERCIONES / PROYECTO': 'USO: OPERACIONES/PROYECTO',
                                    })
ingresos.columns
# Out:
# Index(['CLASIFICACION', 'CODIGO SAP', 'DESCRIPCION DEL MATERIAL', 'UM',
#        'CANTIDAD', 'FECHA DE INGRESO', 'RESERVA', 'GUIA DESPACHO', 'OC',
#        'USO: OPERACIONES/PROYECTO', 'RECIBIDO POR', 'UBICACION', 'EMPRESA',
#        'PRECIO UNITARIO', 'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %% [markdown]
# ### Categorias únicas por columna

# %%
ingresos['CLASIFICACION'].unique()
# Out:
# array(['VALVULAS', 'IMPERMEABILIAZACIÓN ', 'SERVICIOS GENERALES',
#        'OBRAS CIVILES ', 'PIEZAS ESPECIALES', 'PIPING ',
#        'ILUMINACION EMPALIZADA', 'TALLER BERLIAM', 'HUMECTACIÓN ', 0,
#        'RIEGO MURO TRANQUE', 'INSTRUMENTACIÓN GEOTECNICA', nan],
#       dtype=object)

# %%
ingresos[ingresos['CLASIFICACION'] == 0]
# Out:
#     CLASIFICACION CODIGO SAP                      DESCRIPCION DEL MATERIAL  \
# 272             0   11220592  MAURO TUERCA STORZ 4 PULGADAS LINEA DE RIEGO
#
#      UM  CANTIDAD FECHA DE INGRESO RESERVA GUIA DESPACHO          OC  \
# 272  UN      50.0       2025-12-18     NaN          9773  4510248743
#
#     USO: OPERACIONES/PROYECTO    RECIBIDO POR      UBICACION       EMPRESA  \
# 272     PROYECTO HABILITADOR   KAREM GONZALEZ  BODEGA NOATUM  VERTICAL SPA
#
#      PRECIO UNITARIO  TOTAL NETO OBSERVACIONES
# 272          17037.0    851850.0           NaN

# %%
ingresos.loc[ingresos['CLASIFICACION'] == 0, 'CLASIFICACION'] = 'PIEZAS ESPECIALIES'

# %%
ingresos['CLASIFICACION'].unique()
# Out:
# array(['VALVULAS', 'IMPERMEABILIAZACIÓN ', 'SERVICIOS GENERALES',
#        'OBRAS CIVILES ', 'PIEZAS ESPECIALES', 'PIPING ',
#        'ILUMINACION EMPALIZADA', 'TALLER BERLIAM', 'HUMECTACIÓN ',
#        'PIEZAS ESPECIALIES', 'RIEGO MURO TRANQUE',
#        'INSTRUMENTACIÓN GEOTECNICA', nan], dtype=object)

# %%
ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CLASIFICACION              291 non-null    object
#  1   CODIGO SAP                 291 non-null    object
#  2   DESCRIPCION DEL MATERIAL   291 non-null    object
#  3   UM                         291 non-null    object
#  4   CANTIDAD                   291 non-null    float64
#  5   FECHA DE INGRESO           291 non-null    datetime64[ns]
#  6   RESERVA                    278 non-null    object
#  7   GUIA DESPACHO              272 non-null    object
#  8   OC                         290 non-null    object
#  9   USO: OPERACIONES/PROYECTO  290 non-null    object
#  10  RECIBIDO POR               291 non-null    object
#  11  UBICACION                  278 non-null    object
#  12  EMPRESA                    290 non-null    object
#  13  PRECIO UNITARIO            290 non-null    float64
#  14  TOTAL NETO                 616 non-null    float64
#  15  OBSERVACIONES              3 non-null      object
# dtypes: datetime64[ns](1), float64(3), object(12)
# memory usage: 77.1+ KB

# %%
ingresos = ingresos.dropna(subset=['CODIGO SAP'])

# %%
ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 291 entries, 0 to 290
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CLASIFICACION              291 non-null    object
#  1   CODIGO SAP                 291 non-null    object
#  2   DESCRIPCION DEL MATERIAL   291 non-null    object
#  3   UM                         291 non-null    object
#  4   CANTIDAD                   291 non-null    float64
#  5   FECHA DE INGRESO           291 non-null    datetime64[ns]
#  6   RESERVA                    278 non-null    object
#  7   GUIA DESPACHO              272 non-null    object
#  8   OC                         290 non-null    object
#  9   USO: OPERACIONES/PROYECTO  290 non-null    object
#  10  RECIBIDO POR               291 non-null    object
#  11  UBICACION                  278 non-null    object
#  12  EMPRESA                    290 non-null    object
#  13  PRECIO UNITARIO            290 non-null    float64
#  14  TOTAL NETO                 291 non-null    float64
#  15  OBSERVACIONES              3 non-null      object
# dtypes: datetime64[ns](1), float64(3), object(12)
# memory usage: 38.6+ KB

# %%
ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 291 entries, 0 to 290
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CLASIFICACION              291 non-null    object
#  1   CODIGO SAP                 291 non-null    object
#  2   DESCRIPCION DEL MATERIAL   291 non-null    object
#  3   UM                         291 non-null    object
#  4   CANTIDAD                   291 non-null    float64
#  5   FECHA DE INGRESO           291 non-null    datetime64[ns]
#  6   RESERVA                    278 non-null    object
#  7   GUIA DESPACHO              272 non-null    object
#  8   OC                         290 non-null    object
#  9   USO: OPERACIONES/PROYECTO  290 non-null    object
#  10  RECIBIDO POR               291 non-null    object
#  11  UBICACION                  278 non-null    object
#  12  EMPRESA                    290 non-null    object
#  13  PRECIO UNITARIO            290 non-null    float64
#  14  TOTAL NETO                 291 non-null    float64
#  15  OBSERVACIONES              3 non-null      object
# dtypes: datetime64[ns](1), float64(3), object(12)
# memory usage: 38.6+ KB

# %%
ingresos['FECHA DE INGRESO'] = ingresos['FECHA DE INGRESO'].astype(str)

# %%
ingresos['UM'].unique()
# Out:
# array(['UN', 'M2', 'ROLLOS', 'M', 'Kg'], dtype=object)

# %%
# Estandarización de categorías y unidades de medida
import sys
sys.path.append('..')
from src.data_process import estandarizar_datos
ingresos, valores_unicos_clasificacion, valores_unicos_um = estandarizar_datos(ingresos)
# Out:
# ✅ Unidades estandarizadas
# ✅ Clasificación estandarizada

# %%
valores_unicos_clasificacion
# Out:
# array(['VALVULAS', 'IMPERMEABILIZACION', 'SERVICIOS GENERALES',
#        'OBRAS CIVILES', 'PIEZAS ESPECIALES', 'PIPING',
#        'ILUMINACION EMPALIZADA', 'TALLER BERLIAM', 'HUMECTACION',
#        'RIEGO MURO TRANQUE', 'INSTRUMENTACION GEOTECNICA'], dtype=object)

# %%
valores_unicos_um
# Out:
# array(['UNIDAD', 'M2', 'ROLLO', 'M', 'KG'], dtype=object)

# %% [markdown]
# ### Verificacion valores nulos

# %%
ingresos.columns
# Out:
# Index(['CLASIFICACION', 'CODIGO SAP', 'DESCRIPCION DEL MATERIAL', 'UM',
#        'CANTIDAD', 'FECHA DE INGRESO', 'RESERVA', 'GUIA DESPACHO', 'OC',
#        'USO: OPERACIONES/PROYECTO', 'RECIBIDO POR', 'UBICACION', 'EMPRESA',
#        'PRECIO UNITARIO', 'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')

# %%
print(ingresos['CLASIFICACION'].isnull().sum())
print(ingresos['CODIGO SAP'].isnull().sum())
print(ingresos['DESCRIPCION DEL MATERIAL'].isnull().sum())
print(ingresos['UM'].isnull().sum())
print(ingresos['CANTIDAD'].isnull().sum())
print(ingresos['FECHA DE INGRESO'].isnull().sum())
print(ingresos['RESERVA'].isnull().sum())
print(ingresos['GUIA DESPACHO'].isnull().sum())
print(ingresos['OC'].isnull().sum())
print(ingresos['USO: OPERACIONES/PROYECTO'].isnull().sum())
print(ingresos['RECIBIDO POR'].isnull().sum())
print(ingresos['UBICACION'].isnull().sum())
print(ingresos['EMPRESA'].isnull().sum())
print(ingresos['PRECIO UNITARIO'].isnull().sum())
print(ingresos['TOTAL NETO'].isnull().sum())
print(ingresos['OBSERVACIONES'].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 13
# 19
# 1
# 1
# 0
# 13
# 1
# 1
# 0
# 288

# %%
ingresos[ingresos['PRECIO UNITARIO'].isnull()]
# Out:
#          CLASIFICACION CODIGO SAP  \
# 280  PIEZAS ESPECIALES   11222641
#
#                               DESCRIPCION DEL MATERIAL      UM  CANTIDAD  \
# 280  MAURO SPOOL SPL-10 PIEZA ESPECIAL 10" CON VENT...  UNIDAD       9.0
#
#     FECHA DE INGRESO  RESERVA GUIA DESPACHO          OC  \
# 280       2026-01-01  5315739     REINGRESO  4510246163
#
#     USO: OPERACIONES/PROYECTO    RECIBIDO POR UBICACION  \
# 280     PROYECTO HABILITADOR   KAREM GONZALEZ    COSAPI
#
#                          EMPRESA  PRECIO UNITARIO  TOTAL NETO OBSERVACIONES
# 280  MAESTRANZA FAJARDO LIMITADA              NaN         0.0           NaN

# %% [markdown]
# # Carga

# %%
import sys
import sqlite3
sys.path.append('..')

from src.database import InventarioDatabase

# instanciamos la base de datos
db = InventarioDatabase('../src/db/inventario_lp02.db')
# Creamos la tabla insumos en la base de datos
conexion = sqlite3.connect('../src/db/inventario_lp02.db')
cursor = conexion.cursor()
cursor.execute('''
        CREATE TABLE IF NOT EXISTS ingresos (
            "CLASIFICACION" TEXT NOT NULL,
            "CODIGO SAP" TEXT NOT NULL,
            "DESCRIPCION DEL MATERIAL" TEXT NOT NULL,
            "UM" TEXT NOT NULL,
            "CANTIDAD" INTEGER NOT NULL,
            "FECHA DE INGRESO" DATE NOT NULL,
            "RESERVA" TEXT,
            "GUIA DESPACHO" TEXT,
            "OC" TEXT,
            "USO: OPERACIONES/PROYECTO" TEXT,
            "RECIBIDO POR" TEXT,
            "UBICACION" TEXT,
            "EMPRESA" TEXT,
            "PRECIO UNITARIO" REAL,
            "OBSERVACIONES" TEXT,
            FOREIGN KEY("CODIGO SAP") REFERENCES insumos("CODIGO SAP")
        )
    ''')
consulta = cursor.fetchall()
conexion.close()

# %%
# conexion = sqlite3.connect('../src/db/inventario_lp02.db')
# cursor = conexion.cursor()
# tablas = pd.read_sql_query("DROP TABLE ingresos", conexion)
# conexion.close()

# %%
# from src.database import InventarioDatabase

# isnertar el dataframe:
for index, row in ingresos.iterrows():
    db.insert_ingreso(
        codigo_sap=row['CODIGO SAP'],
        clasificacion=row['CLASIFICACION'],
        descripcion=row['DESCRIPCION DEL MATERIAL'],
        um=row['UM'],
        cantidad=row['CANTIDAD'],
        fecha_ingreso=row['FECHA DE INGRESO'],
        reserva=row.get('RESERVA'),
        guia_despacho=row.get('GUIA DESPACHO'),
        oc=row.get('OC'),
        uso=row.get('USO: OPERACIONES/PROYECTO'),
        recibido_por=row.get('RECIBIDO POR'),
        ubicacion=row.get('UBICACION'),
        empresa=row.get('EMPRESA'),
        precio_unitario=row.get('PRECIO UNITARIO'),
        observaciones=row.get('OBSERVACIONES')
    )
# Out:
# ✓ Ingreso con código SAP 11178702 insertado correctamente.
# ✓ Ingreso con código SAP 11117559 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 1111112 insertado correctamente.
# ✓ Ingreso con código SAP 1111111 insertado correctamente.
# ✓ Ingreso con código SAP 11220105 insertado correctamente.
# ✓ Ingreso con código SAP 11220104 insertado correctamente.
# ✓ Ingreso con código SAP 11220103 insertado correctamente.
# ✓ Ingreso con código SAP 11220102 insertado correctamente.
# ✓ Ingreso con código SAP 11220177 insertado correctamente.
# ✓ Ingreso con código SAP 11220176 insertado correctamente.
# ✓ Ingreso con código SAP 11220175 insertado correctamente.
# ✓ Ingreso con código SAP 11220174 insertado correctamente.
# ✓ Ingreso con código SAP 11220173 insertado correctamente.
# ✓ Ingreso con código SAP 11220172 insertado correctamente.
# ✓ Ingreso con código SAP 22003591 insertado correctamente.
# ✓ Ingreso con código SAP 11220181 insertado correctamente.
# ✓ Ingreso con código SAP 11219877 insertado correctamente.
# ✓ Ingreso con código SAP 11220121 insertado correctamente.
# ✓ Ingreso con código SAP 22003208 insertado correctamente.
# ✓ Ingreso con código SAP 11220106 insertado correctamente.
# ✓ Ingreso con código SAP 10-000010 insertado correctamente.
# ✓ Ingreso con código SAP 40-000040 insertado correctamente.
# ✓ Ingreso con código SAP 60-000060 insertado correctamente.
# ✓ Ingreso con código SAP 70-000070 insertado correctamente.
# ✓ Ingreso con código SAP 90-000090 insertado correctamente.
# ✓ Ingreso con código SAP 100-0000100 insertado correctamente.
# ✓ Ingreso con código SAP 140-0000140 insertado correctamente.
# ✓ Ingreso con código SAP 150-0000150 insertado correctamente.
# ✓ Ingreso con código SAP 160-0000160 insertado correctamente.
# ✓ Ingreso con código SAP 170-0000170 insertado correctamente.
# ✓ Ingreso con código SAP 22015853 insertado correctamente.
# ✓ Ingreso con código SAP 1111113 insertado correctamente.
# ✓ Ingreso con código SAP 22003591 insertado correctamente.
# ✓ Ingreso con código SAP 20-000020 insertado correctamente.
# ✓ Ingreso con código SAP 50-000050 insertado correctamente.
# ✓ Ingreso con código SAP 80-000080 insertado correctamente.
# ✓ Ingreso con código SAP 110-0000110 insertado correctamente.
# ✓ Ingreso con código SAP 120-0000120 insertado correctamente.
# ✓ Ingreso con código SAP 130-0000130 insertado correctamente.
# ✓ Ingreso con código SAP 1111114 insertado correctamente.
# ✓ Ingreso con código SAP 1111115 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11019930 insertado correctamente.
# ✓ Ingreso con código SAP 11087505 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 1111116 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11220106 insertado correctamente.
# ✓ Ingreso con código SAP 11185704 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP AA156414 insertado correctamente.
# ✓ Ingreso con código SAP 22003591 insertado correctamente.
# ✓ Ingreso con código SAP 11210094 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11216847 insertado correctamente.
# ✓ Ingreso con código SAP 11216848 insertado correctamente.
# ✓ Ingreso con código SAP 11216460 insertado correctamente.
# ✓ Ingreso con código SAP 11216462 insertado correctamente.
# ✓ Ingreso con código SAP 11216344 insertado correctamente.
# ✓ Ingreso con código SAP 11216345 insertado correctamente.
# ✓ Ingreso con código SAP 11216830 insertado correctamente.
# ✓ Ingreso con código SAP 11216347 insertado correctamente.
# ✓ Ingreso con código SAP 11216349 insertado correctamente.
# ✓ Ingreso con código SAP 22003591 insertado correctamente.
# ✓ Ingreso con código SAP 11111117 insertado correctamente.
# ✓ Ingreso con código SAP 11111118 insertado correctamente.
# ✓ Ingreso con código SAP 11111119 insertado correctamente.
# ✓ Ingreso con código SAP 11111120 insertado correctamente.
# ✓ Ingreso con código SAP 11111121 insertado correctamente.
# ✓ Ingreso con código SAP 11111122 insertado correctamente.
# ✓ Ingreso con código SAP 11111123 insertado correctamente.
# ✓ Ingreso con código SAP 11111124 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11220106 insertado correctamente.
# ✓ Ingreso con código SAP 11009710 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 11174821 insertado correctamente.
# ✓ Ingreso con código SAP 11221696 insertado correctamente.
# ✓ Ingreso con código SAP 11221697 insertado correctamente.
# ✓ Ingreso con código SAP 11221698 insertado correctamente.
# ✓ Ingreso con código SAP 11221699 insertado correctamente.
# ✓ Ingreso con código SAP 11221700 insertado correctamente.
# ✓ Ingreso con código SAP 11221701 insertado correctamente.
# ✓ Ingreso con código SAP 11221703 insertado correctamente.
# ✓ Ingreso con código SAP 11221696 insertado correctamente.
# ✓ Ingreso con código SAP 11221697 insertado correctamente.
# ✓ Ingreso con código SAP 11221698 insertado correctamente.
# ✓ Ingreso con código SAP 11221699 insertado correctamente.
# ✓ Ingreso con código SAP 11221700 insertado correctamente.
# ✓ Ingreso con código SAP 11221701 insertado correctamente.
# ✓ Ingreso con código SAP 11221703 insertado correctamente.
# ✓ Ingreso con código SAP 11221696 insertado correctamente.
# ✓ Ingreso con código SAP 11221697 insertado correctamente.
# ✓ Ingreso con código SAP 11221698 insertado correctamente.
# ✓ Ingreso con código SAP 11221699 insertado correctamente.
# ✓ Ingreso con código SAP 11221700 insertado correctamente.
# ✓ Ingreso con código SAP 11221701 insertado correctamente.
# ✓ Ingreso con código SAP 11221703 insertado correctamente.
# ✓ Ingreso con código SAP 11221696 insertado correctamente.
# ✓ Ingreso con código SAP 11221697 insertado correctamente.
# ✓ Ingreso con código SAP 11221698 insertado correctamente.
# ✓ Ingreso con código SAP 11221699 insertado correctamente.
# ✓ Ingreso con código SAP 11221700 insertado correctamente.
# ✓ Ingreso con código SAP 11221701 insertado correctamente.
# ✓ Ingreso con código SAP 11221703 insertado correctamente.
# ✓ Ingreso con código SAP 11214445 insertado correctamente.
# ✓ Ingreso con código SAP 11214445 insertado correctamente.
# ✓ Ingreso con código SAP 11214446 insertado correctamente.
# ✓ Ingreso con código SAP 11214521 insertado correctamente.
# ✓ Ingreso con código SAP 11214520 insertado correctamente.
# ✓ Ingreso con código SAP 11214444 insertado correctamente.
# ✓ Ingreso con código SAP 11218044 insertado correctamente.
# ✓ Ingreso con código SAP 11212170 insertado correctamente.
# ✓ Ingreso con código SAP 11212165 insertado correctamente.
# ✓ Ingreso con código SAP 11219144 insertado correctamente.
# ✓ Ingreso con código SAP 11219143 insertado correctamente.
# ✓ Ingreso con código SAP 11214516 insertado correctamente.
# ✓ Ingreso con código SAP 11218782 insertado correctamente.
# ✓ Ingreso con código SAP 11218783 insertado correctamente.
# ✓ Ingreso con código SAP 11218784 insertado correctamente.
# ✓ Ingreso con código SAP 11217092 insertado correctamente.
# ✓ Ingreso con código SAP 11217089 insertado correctamente.
# ✓ Ingreso con código SAP 11218787 insertado correctamente.
# ✓ Ingreso con código SAP 11219139 insertado correctamente.
# ✓ Ingreso con código SAP 11219819 insertado correctamente.
# ✓ Ingreso con código SAP 11219820 insertado correctamente.
# ✓ Ingreso con código SAP 11219822 insertado correctamente.
# ✓ Ingreso con código SAP 11220096 insertado correctamente.
# ✓ Ingreso con código SAP 11220097 insertado correctamente.
# ✓ Ingreso con código SAP 11220099 insertado correctamente.
# ✓ Ingreso con código SAP 11220101 insertado correctamente.
# ✓ Ingreso con código SAP 11220570 insertado correctamente.
# ✓ Ingreso con código SAP 11212162 insertado correctamente.
# ✓ Ingreso con código SAP 11009710 insertado correctamente.
# ✓ Ingreso con código SAP 22015472 insertado correctamente.
# ✓ Ingreso con código SAP 11216885 insertado correctamente.
# ✓ Ingreso con código SAP 11219140 insertado correctamente.
# ✓ Ingreso con código SAP 11219141 insertado correctamente.
# ✓ Ingreso con código SAP 11219142 insertado correctamente.
# ✓ Ingreso con código SAP 11219144 insertado correctamente.
# ✓ Ingreso con código SAP 11217711 insertado correctamente.
# ✓ Ingreso con código SAP 11217695 insertado correctamente.
# ✓ Ingreso con código SAP 11212174 insertado correctamente.
# ✓ Ingreso con código SAP 11212171 insertado correctamente.
# ✓ Ingreso con código SAP 11221696 insertado correctamente.
# ✓ Ingreso con código SAP 11221697 insertado correctamente.
# ✓ Ingreso con código SAP 11221698 insertado correctamente.
# ✓ Ingreso con código SAP 11221699 insertado correctamente.
# ✓ Ingreso con código SAP 11221700 insertado correctamente.
# ✓ Ingreso con código SAP 11221701 insertado correctamente.
# ✓ Ingreso con código SAP 11221703 insertado correctamente.
# ✓ Ingreso con código SAP 11221696 insertado correctamente.
# ✓ Ingreso con código SAP 11221698 insertado correctamente.
# ✓ Ingreso con código SAP 11221699 insertado correctamente.
# ✓ Ingreso con código SAP 11221700 insertado correctamente.
# ✓ Ingreso con código SAP 11221701 insertado correctamente.
# ✓ Ingreso con código SAP 11221703 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP SPY4153 insertado correctamente.
# ✓ Ingreso con código SAP 11211977 insertado correctamente.
# ✓ Ingreso con código SAP 22003321 insertado correctamente.
# ✓ Ingreso con código SAP 22003328 insertado correctamente.
# ✓ Ingreso con código SAP 22003997 insertado correctamente.
# ✓ Ingreso con código SAP 22003328 insertado correctamente.
# ✓ Ingreso con código SAP I0610418 insertado correctamente.
# ✓ Ingreso con código SAP I0610421 insertado correctamente.
# ✓ Ingreso con código SAP I0607421 insertado correctamente.
# ✓ Ingreso con código SAP N0198615 insertado correctamente.
# ✓ Ingreso con código SAP I0610434 insertado correctamente.
# ✓ Ingreso con código SAP I0610398 insertado correctamente.
# ✓ Ingreso con código SAP I0606013 insertado correctamente.
# ✓ Ingreso con código SAP I0606014 insertado correctamente.
# ✓ Ingreso con código SAP I0606015 insertado correctamente.
# ✓ Ingreso con código SAP I0606016 insertado correctamente.
# ✓ Ingreso con código SAP I0606017 insertado correctamente.
# ✓ Ingreso con código SAP I0606018 insertado correctamente.
# ✓ Ingreso con código SAP N0263035 insertado correctamente.
# ✓ Ingreso con código SAP N0263039 insertado correctamente.
# ✓ Ingreso con código SAP N0263040 insertado correctamente.
# ✓ Ingreso con código SAP N0263046 insertado correctamente.
# ✓ Ingreso con código SAP N0263047 insertado correctamente.
# ✓ Ingreso con código SAP I0607772 insertado correctamente.
# ✓ Ingreso con código SAP I0607502 insertado correctamente.
# ✓ Ingreso con código SAP I0607501 insertado correctamente.
# ✓ Ingreso con código SAP I0607499 insertado correctamente.
# ✓ Ingreso con código SAP I0607498 insertado correctamente.
# ✓ Ingreso con código SAP I0607497 insertado correctamente.
# ✓ Ingreso con código SAP 1111125 insertado correctamente.
# ✓ Ingreso con código SAP 1111125 insertado correctamente.
# ✓ Ingreso con código SAP 1111126 insertado correctamente.
# ✓ Ingreso con código SAP 1111127 insertado correctamente.
# ✓ Ingreso con código SAP 1111128 insertado correctamente.
# ✓ Ingreso con código SAP 1111129 insertado correctamente.
# ✓ Ingreso con código SAP 1111130 insertado correctamente.
# ✓ Ingreso con código SAP 1111131 insertado correctamente.
# ✓ Ingreso con código SAP 1111132 insertado correctamente.
# ✓ Ingreso con código SAP 1111133 insertado correctamente.
# ✓ Ingreso con código SAP 1111134 insertado correctamente.
# ✓ Ingreso con código SAP 1111135 insertado correctamente.
# ✓ Ingreso con código SAP 1111136 insertado correctamente.
# ✓ Ingreso con código SAP 1111137 insertado correctamente.
# ✓ Ingreso con código SAP 1111138 insertado correctamente.
# ✓ Ingreso con código SAP 1111125 insertado correctamente.
# ✓ Ingreso con código SAP 1111139 insertado correctamente.
# ✓ Ingreso con código SAP 1111145 insertado correctamente.
# ✓ Ingreso con código SAP 1111140 insertado correctamente.
# ✓ Ingreso con código SAP 1111141 insertado correctamente.
# ✓ Ingreso con código SAP 1111142 insertado correctamente.
# ✓ Ingreso con código SAP 1111143 insertado correctamente.
# ✓ Ingreso con código SAP 1111146 insertado correctamente.
# ✓ Ingreso con código SAP FER151723 insertado correctamente.
# ✓ Ingreso con código SAP FER151724 insertado correctamente.
# ✓ Ingreso con código SAP FER151725 insertado correctamente.
# ✓ Ingreso con código SAP NA38014HD2 insertado correctamente.
# ✓ Ingreso con código SAP NA38032S20 insertado correctamente.
# ✓ Ingreso con código SAP NA04055N25 insertado correctamente.
# ✓ Ingreso con código SAP NA38016P14 insertado correctamente.
# ✓ Ingreso con código SAP NA38031S30 insertado correctamente.
# ✓ Ingreso con código SAP 85300 insertado correctamente.
# ✓ Ingreso con código SAP 85240 insertado correctamente.
# ✓ Ingreso con código SAP 85258 insertado correctamente.
# ✓ Ingreso con código SAP 142564 insertado correctamente.
# ✓ Ingreso con código SAP 20017 insertado correctamente.
# ✓ Ingreso con código SAP 110516 insertado correctamente.
# ✓ Ingreso con código SAP 110518 insertado correctamente.
# ✓ Ingreso con código SAP 110519 insertado correctamente.
# ✓ Ingreso con código SAP 107883 insertado correctamente.
# ✓ Ingreso con código SAP FZH54987 insertado correctamente.
# ✓ Ingreso con código SAP FZH55015 insertado correctamente.
# ✓ Ingreso con código SAP FZH18729 insertado correctamente.
# ✓ Ingreso con código SAP FZH13926 insertado correctamente.
# ✓ Ingreso con código SAP FZH55017 insertado correctamente.
# ✓ Ingreso con código SAP FZH55018 insertado correctamente.
# ✓ Ingreso con código SAP FZH55020 insertado correctamente.
# ✓ Ingreso con código SAP FZH54685 insertado correctamente.
# ✓ Ingreso con código SAP FZH55023 insertado correctamente.
# ✓ Ingreso con código SAP FZH10227 insertado correctamente.
# ✓ Ingreso con código SAP FZH10391 insertado correctamente.
# ✓ Ingreso con código SAP FZH43307 insertado correctamente.
# ✓ Ingreso con código SAP FZH51965 insertado correctamente.
# ✓ Ingreso con código SAP FZH54995 insertado correctamente.
# ✓ Ingreso con código SAP 11087505 insertado correctamente.
# ✓ Ingreso con código SAP 1111112 insertado correctamente.
# ✓ Ingreso con código SAP 11220592 insertado correctamente.
# ✓ Ingreso con código SAP 10-00010 insertado correctamente.
# ✓ Ingreso con código SAP FZH55024 insertado correctamente.
# ✓ Ingreso con código SAP 11220569 insertado correctamente.
# ✓ Ingreso con código SAP 11225570 insertado correctamente.
# ✓ Ingreso con código SAP 11225571 insertado correctamente.
# ✓ Ingreso con código SAP 11019047 insertado correctamente.
# ✓ Ingreso con código SAP 11019047 insertado correctamente.
# ✓ Ingreso con código SAP 11222641 insertado correctamente.
# ✓ Ingreso con código SAP 22002945 insertado correctamente.
# ✓ Ingreso con código SAP 11221838 insertado correctamente.
# ✓ Ingreso con código SAP 1111144 insertado correctamente.
# ✓ Ingreso con código SAP 1111128 insertado correctamente.
# ✓ Ingreso con código SAP 10-00010 insertado correctamente.
# ✓ Ingreso con código SAP 20-00020 insertado correctamente.
# ✓ Ingreso con código SAP NA38032S20 insertado correctamente.
# ✓ Ingreso con código SAP 159387 insertado correctamente.
# ✓ Ingreso con código SAP N0923151 insertado correctamente.
# ✓ Ingreso con código SAP 1111150 insertado correctamente.

# %%
ingresos['CANTIDAD'].isnull().sum()
# Out:
# np.int64(0)

# %%
# import sqlite3
conexion = sqlite3.connect('../src/db/inventario_lp02.db')
cursor = conexion.cursor()
cursor.execute("SELECT * FROM sqlite_master")
consulta = cursor.fetchall()
# tablas = pd.read_sql_query("DROP TABLE insumos", conexion)
conexion.close()
consulta
# tablas
# Out:
# [('table',
#   'insumos',
#   'insumos',
#   2,
#   'CREATE TABLE insumos (\n            "CODIGO SAP" TEXT PRIMARY KEY,\n            "DESCRIPCION DEL MATERIAL" TEXT,\n            "CLASIFICACION" TEXT,\n            "UM" TEXT,\n            "OBSERVACIONES" TEXT\n        )'),
#  ('index', 'sqlite_autoindex_insumos_1', 'insumos', 3, None),
#  ('table',
#   'ingresos',
#   'ingresos',
#   16,
#   'CREATE TABLE ingresos (\n            "CLASIFICACION" TEXT NOT NULL,\n            "CODIGO SAP" TEXT NOT NULL,\n            "DESCRIPCION DEL MATERIAL" TEXT NOT NULL,\n            "UM" TEXT NOT NULL,\n            "CANTIDAD" INTEGER NOT NULL,\n            "FECHA DE INGRESO" DATE NOT NULL,\n            "RESERVA" TEXT,\n            "GUIA DESPACHO" TEXT,\n            "OC" TEXT,\n            "USO: OPERACIONES/PROYECTO" TEXT,\n            "RECIBIDO POR" TEXT,\n            "UBICACION" TEXT,\n            "EMPRESA" TEXT,\n            "PRECIO UNITARIO" REAL,\n            "OBSERVACIONES" TEXT,\n            FOREIGN KEY("CODIGO SAP") REFERENCES insumos("CODIGO SAP")\n        )')]

# %%
ingresos.columns
# Out:
# Index(['CLASIFICACION', 'CODIGO SAP', 'DESCRIPCION DEL MATERIAL', 'UM',
#        'CANTIDAD', 'FECHA DE INGRESO', 'RESERVA', 'GUIA DESPACHO', 'OC',
#        'USO: OPERACIONES/PROYECTO', 'RECIBIDO POR', 'UBICACION', 'EMPRESA',
#        'PRECIO UNITARIO', 'TOTAL NETO', 'OBSERVACIONES'],
#       dtype='object')
